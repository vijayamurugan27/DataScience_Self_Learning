# %%
pip install ipywidgets
# Out:
# ...
#      ---------------------------------------- 0.0/137.8 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/137.8 kB 660.6 kB/s eta 0:00:01
#      -------- ---------------------------- 30.7/137.8 kB 660.6 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/137.8 kB 245.8 kB/s eta 0:00:01
#      ---------------------- -------------- 81.9/137.8 kB 353.1 kB/s eta 0:00:01
#      -------------------------------- --- 122.9/137.8 kB 379.3 kB/s eta 0:00:01
#      ------------------------------------ 137.8/137.8 kB 407.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.0 MB 1.3 MB/s eta 0:00:02
#       --------------------------------------- 0.0/2.0 MB 1.3 MB/s eta 0:00:02
#       --------------------------------------- 0.0/2.0 MB 279.3 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/2.0 MB 363.1 kB/s eta 0:00:06
# ...

# %%
pip install pandas
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#      --------------------------------------- 0.1/10.3 MB 980.4 kB/s eta 0:00:11
#       --------------------------------------- 0.2/10.3 MB 1.1 MB/s eta 0:00:10
#       --------------------------------------- 0.3/10.3 MB 1.2 MB/s eta 0:00:09
#      - -------------------------------------- 0.3/10.3 MB 1.3 MB/s eta 0:00:08
#      -- ------------------------------------- 0.6/10.3 MB 1.9 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/10.3 MB 2.0 MB/s eta 0:00:05
#      --- ------------------------------------ 0.9/10.3 MB 2.1 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.1/10.3 MB 2.1 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.3/10.3 MB 2.2 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.4/10.3 MB 2.3 MB/s eta 0:00:04
# ...

# %%
pip install numpy

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.6 MB 1.3 MB/s eta 0:00:06
#      ---------------------------------------- 0.1/7.6 MB 777.7 kB/s eta 0:00:10
#      ---------------------------------------- 0.1/7.6 MB 1.0 MB/s eta 0:00:08
#       --------------------------------------- 0.2/7.6 MB 952.6 kB/s eta 0:00:08
#      - -------------------------------------- 0.3/7.6 MB 1.2 MB/s eta 0:00:07
#      - -------------------------------------- 0.4/7.6 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/7.6 MB 1.7 MB/s eta 0:00:05
#      --- ------------------------------------ 0.6/7.6 MB 1.7 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/7.6 MB 1.8 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.8/7.6 MB 1.8 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.0/7.6 MB 1.9 MB/s eta 0:00:04
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# data= pd.read_csv("D:\datasciencewithMS\Datas_csv\JC-202302-citibike-tripdata.csv\JC-202302-citibike-tripdata.csv")
data= pd.read_csv("D:/datasciencewithMS/Datas_csv/archive/test-data.csv")
data.head()
df = pd.DataFrame(data)

name = df['Name'].head(5)
price = df['Mileage'].head(5)
fig = plt.figure(figsize =(20, 10))
plt.bar(name[0:5], price[0:5])
# plt.bar()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# data= pd.read_csv("D:\datasciencewithMS\Datas_csv\JC-202302-citibike-tripdata.csv\JC-202302-citibike-tripdata.csv")
data= pd.read_csv("D:/datasciencewithMS/Datas_csv/archive/test-data.csv")
data.head()
df = pd.DataFrame(data)

name = df['Name'].head(12)
price = df['Mileage'].head(12)


fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(name, price)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('Sports car and their price in crore',
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 25
#      23 ax.xaxis.set_tick_params(pad = 5)
#      24 ax.yaxis.set_tick_params(pad = 10)
# ---> 25 ax.grid(b = True, color ='grey',
#      26         linestyle ='-.', linewidth = 0.5,
#      27         alpha = 0.2)
#      29 ax.invert_yaxis()
#      31 for i in ax.patches:
#
# File d:\datasciencewithMS\DataScienceWithMs\.venv\Lib\site-packages\matplotlib\axes\_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
#    3196     self.yaxis.grid(visible, which=which, **kwargs)
#
# ...
