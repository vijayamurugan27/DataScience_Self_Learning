# %%
df = pd.read_csv('/datasciencewithMS/DataScienceWithMs/4Fourthvideo/archive/tmdb_5000_movies.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('/datasciencewithMS/DataScienceWithMs/4Fourthvideo/archive/tmdb_5000_movies.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

df = pd.read_csv('/datasciencewithMS/DataScienceWithMs/4Fourthvideo/archive/tmdb_5000_movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df_higherRunTime = df[df['runtime']>= 180]['title']

print("The number of movies with such a runtime are ", df_higherRunTime.shape[0] )
df_higherRunTime
# Out:
# The number of movies with such a runtime are  47
# 24                                          King Kong
# 25                                            Titanic
# 110                                      Pearl Harbor
# 298                           The Wolf of Wall Street
# 329     The Lord of the Rings: The Return of the King
# 676                                        Wyatt Earp
# 690                                    The Green Mile
# 855                                 Gods and Generals
# 880                                        Grindhouse
# 1091                                            Nixon
# 1109                                    Heaven's Gate
# 1125                                        Cleopatra
# 1181                                              JFK
# 1333                                         Magnolia
# 1387                                        Malcolm X
# 1456                                   Bound by Honor
# ...

# %%
# printing all columns of the dataframe
print(df.columns.tolist())
# Out:
# ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']

# %%
df['runtime']
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4803, dtype: float64

# %%
a = df[df['runtime']>=100]['title']

# %%
df['title']
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: title, Length: 4803, dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']

# %%
df.groupby('original_title')['vote_count'].mean().sort_values(ascending=False)
# Out:
# original_title
# Inception                 13752.0
# The Dark Knight           12002.0
# Avatar                    11800.0
# The Avengers              11776.0
# Deadpool                  10995.0
#                            ...
# The Work and The Story        0.0
# The Young Unknowns            0.0
# Theresa Is a Mother           0.0
# Give Me Shelter               0.0
# The Deported                  0.0
# Name: vote_count, Length: 4801, dtype: float64

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# df.columns.value_counts()
df.columns.to_list()
# Out:
# ['budget',
#  'genres',
#  'homepage',
#  'id',
#  'keywords',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'vote_average',
#  'vote_count']

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import Series , DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(data = df, x = "release_date", y = "revenue")
plt.title("Highest Grossing films")
# Out:
# Text(0.5, 1.0, 'Highest Grossing films')

# %%
sns.barplot(data = df, x = "release_date", y = "vote_count")
plt.title("Highest Grossing films")
# Out:
# Text(0.5, 1.0, 'Highest Grossing films')

# %%
sns.barplot(data = df, x = "release_date", y = "revenue")
plt.title("Highest Grossing films")
plt.show()

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df.sample(n = 2)
# Out:
#         budget                                             genres homepage  \
# 2805  12300000  [{"id": 16, "name": "Animation"}, {"id": 12, "...      NaN
# 2467  16000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...      NaN
#
#          id                                           keywords  \
# 2805  12144  [{"id": 746, "name": "vulkan"}, {"id": 936, "n...
# 2467  16161  [{"id": 641, "name": "single parent"}, {"id": ...
#
#      original_language        original_title  \
# 2805                en  The Land Before Time
# 2467                en              Baby Boy
#
#                                                overview  popularity  \
# 2805  An orphaned brontosaurus named Littlefoot sets...   28.670193
# 2467  The story of Jody, a misguided, 20-year-old Af...    7.854989
#
#                                    production_companies  \
# 2805  [{"name": "Lucasfilm", "id": 1}, {"name": "Uni...
# 2467  [{"name": "Columbia Pictures", "id": 5}, {"nam...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df.columns.to_list()
# Out:
# ['budget',
#  'genres',
#  'homepage',
#  'id',
#  'keywords',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'vote_average',
#  'vote_count']

# %%
df.nlargest(10, 'vote_count')[['original_title','title','tagline' ]]
Dopedirectors = pd.DataFrame(df.nlargest(10, 'vote_count')[['original_title','title','tagline','genres','revenue','release_date' ]])
Dopedirectors
# Out:
#               original_title                    title  \
# 96                 Inception                Inception
# 65           The Dark Knight          The Dark Knight
# 0                     Avatar                   Avatar
# 16              The Avengers             The Avengers
# 788                 Deadpool                 Deadpool
# 95              Interstellar             Interstellar
# 287         Django Unchained         Django Unchained
# 94   Guardians of the Galaxy  Guardians of the Galaxy
# 426         The Hunger Games         The Hunger Games
# 127       Mad Max: Fury Road       Mad Max: Fury Road
#
#                                                tagline  \
# 96                Your mind is the scene of the crime.
# 65                                     Why So Serious?
# 0                          Enter the World of Pandora.
# 16                             Some assembly required.
# 788            Witness the beginning of a happy ending
# ...

# %%
sns.scatterplot(data = Dopedirectors, x ="release_date", y = "title", hue="release_date" )
plt.title = ("highest grossing films")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x ="original_title", y  = Dopedirectors.index, data = Dopedirectors )
# Out:
# <Axes: xlabel='original_title'>

# %%
sns.barplot(x ="original_title", y  = Dopedirectors.revenue, data = Dopedirectors )
# Out:
# <Axes: xlabel='original_title', ylabel='revenue'>

# %%
sns.barplot(x =Dopedirectors.revenue, y  = "release_date", data = Dopedirectors )
# Out:
# <Axes: xlabel='revenue', ylabel='release_date'>
